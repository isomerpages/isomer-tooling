# %%
from bs4 import BeautifulSoup
import requests
import re
import json
import os
import urllib.request
import shutil
import math
import pandas as pd

#######################################
#         File EXTRACTOOOOOOOR        #
#######################################

# Define target website
URL = "https://www.nparks.gov.sg/avs/resources?section=All&type=All&category=All&page=1&pageSize=10"
# Define the domain
domain = "https://www.nparks.gov.sg"

# Define variables
files = {}
folder_path = "docs"
hrefSchema = {}

# Define custom file path after /files (e.g. "/folder1/folder2")
# Output -> "/files/folder1/folder2/document.pdf"
docsFolderPath = ""

# Define the folder path
file_name = 'docs'
file_name_zip = file_name+'.zip'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5',
    'Connection': 'keep-alive',
}

# Remove existing folders and/or files if exists from previous session
try:
    while os.path.exists(file_name) or os.path.exists(file_name_zip) is True:
        shutil.rmtree(file_name)
        os.remove(file_name_zip)
except:
  pass

# Generate dictionary
def getDictionary(link):
  count = 0
  URL = f"{link}"

  # Pulls entire HTML code and parse it through BeautifulSoup
  page = requests.get(URL, headers=headers)
  soup = BeautifulSoup(page.content, "html.parser")

  # Loop through all anchor tags to find downloadable files
  for i in soup.find_all(['a']):
    href = i.get('href')
    # Check if the link is a document link
    if href and '/docs/' in i['href'] or href and 'go.gov.sg' in i['href']:
      # Build dictionary
      files[count] = {"Text": i.text, "File name": i['href'][:i['href'].find('?')].split("/")[-1], "Download Link": i['href'] if 'go.gov.sg' in i['href'] else domain + i['href'] if domain not in i['href'] else i['href'], "File path": f"files{docsFolderPath if True else None}/{i['href'][:i['href'].find('?')].split("/")[-1]}", "Updated link": i['href'][:i['href'].find('?')], "Original link": i['href']}
      r = requests.head(files[count]["Download Link"], allow_redirects=True)
      # Resolve potential redirects
      files[count]["Download Link"] = r.url.split('%')[0]
      files[count]["File name"] = r.url[:r.url.find('?')].split("/")[-1] if '?' in r.url else r.url.split("/")[-1]
      files[count]["File name"] = files[count]["File name"].split('%')[0]

      print(files[count]["Download Link"], files[count]["File name"])
      count += 1
  downloadFiles()

# Download the files based on the constructed dictionary
def downloadFiles():
  # Create the output folder if it doesn't exist
  if not os.path.exists(folder_path):
      os.makedirs(folder_path)

  # Configure request headers for downloading
  headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5',
    'Connection': 'keep-alive',
  }
  opener = urllib.request.build_opener()
  opener.addheaders = [(key, value) for key, value in headers.items()]
  urllib.request.install_opener(opener)

  # Iterate through each file and download it
  for index, value in enumerate(files):
    try:
        # Stores each dictionary item's download link
        url = files[index]['Download Link']

        # Define file path and name
        file_path = os.path.join(f"{folder_path}", f"{files[index]['File name']}")
        
        # Download file
        urllib.request.urlretrieve(url, file_path)

    except Exception as e:
        pass

  # Generate file size metadata and print the JSON schema
  for index, value in enumerate(files):
    try:
        # Debating between dividing 1024 or 1000. Generally 1 Kilo = 1000(grams), But in Binary 1 Kilo = 1024 bytes
        fileSize = str(math.ceil(os.path.getsize(f"docs/{files[index]['File name']}")/1024))
        # Calculate and define file size
        fileSize = fileSize + ' KB' if len(fileSize) <= 3 else str(round((int(fileSize)/1000), 2)) + ' MB' if len(fileSize) >= 4 and len(fileSize) < 7 else str(fileSize) + ' B'    
        
        hrefSchema = {
              "type": "text",
              "marks": [
                {
                  "type": "link",
                  "attrs": {
                    "href": f"/files{docsFolderPath if True else None}/{files[index]['File name']}"
                    }
                }
              ],
              # Original File Name is used as we want to display Circular 1 instead of circular-1
              "text": f"{files[index]['Text']} [{'DOCX' if '.docx' in files[index]['Download Link'] else 'DOC' if '.doc' in files[index]['Download Link'] else 'XLXS' if '.xlxs' in files[index]['Download Link'] else 'XLS' if '.xls' in files[index]['Download Link'] else 'ZIP' if '.zip' in files[index]['Download Link'] else 'PDF'}, {fileSize}]"
            }
        print(json.dumps(hrefSchema))
    except Exception as e:
      pass

getDictionary(URL)

# Export report to .csv
df = pd.DataFrame.from_dict(files, orient='index')
df.to_csv("file-extractor-report.csv", index=False)
# Out:
# https://www.healthprofessionals.gov.sg/docs/librariesprovider2/published-grounds-of-decision/year-2024/01-grounds-of-decision-(241129)-dr-ooi-teik-huat-redacted-for-publn.pdf?sfvrsn=b2370c9d_1 01-grounds-of-decision-(241129)-dr-ooi-teik-huat-redacted-for-publn.pdf
# https://www.healthprofessionals.gov.sg/docs/librariesprovider2/published-grounds-of-decision/year-2024/01-grounds-of-decision-(240814)-dr-chen-yun-hian-christopher-redacted-for-pubn-on-240924.pdf?sfvrsn=586639ca_1 01-grounds-of-decision-(240814)-dr-chen-yun-hian-christopher-redacted-for-pubn-on-240924.pdf
# https://www.healthprofessionals.gov.sg/docs/librariesprovider2/published-grounds-of-decision/year-2024/grounds-of-decision---dr-wong-yoke-meng-(140824).pdf?sfvrsn=23fa2eed_1 grounds-of-decision---dr-wong-yoke-meng-(140824).pdf
# https://www.healthprofessionals.gov.sg/docs/librariesprovider2/published-grounds-of-decision/year-2024/01-grounds-of-decision-(231214)-dr-ling-chia-tien-1-2-anonymised-(for-publn).pdf?sfvrsn=dfe92912_1 01-grounds-of-decision-(231214)-dr-ling-chia-tien-1-2-anonymised-(for-publn).pdf
# https://www.healthprofessionals.gov.sg/docs/librariesprovider2/published-grounds-of-decision/year-2024/01-grounds-of-decision-(240508)-dr-chen-hsing-yu-redacted-for-publn.pdf?sfvrsn=7998e269_1 01-grounds-of-decision-(240508)-dr-chen-hsing-yu-redacted-for-publn.pdf
# https://www.healthprofessionals.gov.sg/docs/librariesprovider2/published-grounds-of-decision/year-2024/01-gd-(240419)-dr-yeo-khee-hong-redacted-for-publn.pdf?sfvrsn=72ed5dbe_1 01-gd-(240419)-dr-yeo-khee-hong-redacted-for-publn.pdf
# https://www.healthprofessionals.gov.sg/docs/librariesprovider2/published-grounds-of-decision/year-2024/01-grounds-of-decision-(231025)-dr-tham-ngiap-boo-redacted-for-publication-(240510).pdf?sfvrsn=e37b7f10_2 01-grounds-of-decision-(231025)-dr-tham-ngiap-boo-redacted-for-publication-(240510).pdf
# https://www.healthprofessionals.gov.sg/docs/librariesprovider2/published-grounds-of-decision/year-2024/01-grounds-of-decision---dr-maninder-singh-(redacted)-v2.pdf?sfvrsn=ecbaa73e_2 01-grounds-of-decision---dr-maninder-singh-(redacted)-v2.pdf
# {"type": "text", "marks": [{"type": "link", "attrs": {"href": "/files/01-grounds-of-decision-(241129)-dr-ooi-teik-huat-redacted-for-publn.pdf"}}], "text": "Disciplinary Tribunal Inquiry for Dr Ooi Teik Huat [PDF, 367 KB]"}
# {"type": "text", "marks": [{"type": "link", "attrs": {"href": "/files/01-grounds-of-decision-(240814)-dr-chen-yun-hian-christopher-redacted-for-pubn-on-240924.pdf"}}], "text": "Disciplinary Tribunal Inquiry for Dr Chen Yun Hian Christopher [PDF, 174 KB]"}
# {"type": "text", "marks": [{"type": "link", "attrs": {"href": "/files/grounds-of-decision---dr-wong-yoke-meng-(140824).pdf"}}], "text": "Disciplinary Tribunal Inquiry for Dr Wong Yoke Meng [PDF, 669 KB]"}
# {"type": "text", "marks": [{"type": "link", "attrs": {"href": "/files/01-grounds-of-decision-(231214)-dr-ling-chia-tien-1-2-anonymised-(for-publn).pdf"}}], "text": "Disciplinary Tribunal Inquiry for Dr Ling Chia Tien [PDF, 572 KB]"}
# {"type": "text", "marks": [{"type": "link", "attrs": {"href": "/files/01-grounds-of-decision-(240508)-dr-chen-hsing-yu-redacted-for-publn.pdf"}}], "text": "Disciplinary Tribunal Inquiry for Dr Chen Hsing Yu [PDF, 457 KB]"}
# {"type": "text", "marks": [{"type": "link", "attrs": {"href": "/files/01-gd-(240419)-dr-yeo-khee-hong-redacted-for-publn.pdf"}}], "text": "Disciplinary Tribunal Inquiry for Dr Yeo Khee Hong [PDF, 444 KB]"}
# {"type": "text", "marks": [{"type": "link", "attrs": {"href": "/files/01-grounds-of-decision-(231025)-dr-tham-ngiap-boo-redacted-for-publication-(240510).pdf"}}], "text": "Disciplinary Tribunal Inquiry for Dr Tham Ngiap Boo [PDF, 490 KB]"}
# {"type": "text", "marks": [{"type": "link", "attrs": {"href": "/files/01-grounds-of-decision---dr-maninder-singh-(redacted)-v2.pdf"}}], "text": "Disciplinary Tribunal Inquiry for Dr Maninder Singh Shahi [PDF, 807 KB]"}

# %%
from bs4 import BeautifulSoup
import requests
import re
import json
import os
import urllib.request
import shutil
import math
import pandas as pd

#######################################
#         Image EXTRACTOOOOOOOR       #
#######################################

# Define target website
URL = "https://www.geri.com.sg/About-Us/Pages/News-Detail.aspx?MID=62"
# Define the domain
domain = "https://www.geri.com.sg"
# Define staging site for redirections report
staging = "https://staging.d361y72dz9pmyk.amplifyapp.com/"

# Define variables
files = {}
folder_path = "images"
hrefSchema = {}

# Define custom file path after /images (e.g. "/folder1/folder2")
# Output -> "/images/folder1/folder2/document.png"
docsFolderPath = ""

# Define the folder path
file_name = 'docs'
file_name_zip = file_name+'.zip'

# Remove existing folders and/or files if exists from previous session
try:
    while os.path.exists(file_name) or os.path.exists(file_name_zip) is True:
        shutil.rmtree(file_name)
        os.remove(file_name_zip)
except:
  pass

def getDictionary(link):
  count = 0
  URL = f"{link}"

  # Pulls entire HTML code and parse it through BeautifulSoup
  page = requests.get(URL)
  soup = BeautifulSoup(page.content, "html.parser")

  # Loop through all anchor tags to find downloadable images
  for i in soup.find_all(['img']):
    try:    
        # Build dictionary
        files[count] = {"Original image name": i['alt'], "Updated image name": i['src'][:i['src'].find('?')].split("/")[-1], "Download link": domain + i['src'], "Staging link": staging + f"images/{docsFolderPath if True else None}{i['src'][:i['src'].find('?')].split("/")[-1]}"}
        print(files[count]["Download link"], files[count]["Original image name"])
        count += 1
        
    except Exception as e:
        pass

  downloadFiles()

# Download the images based on the constructed dictionary
def downloadFiles():
  # Create the output folder if it doesn't exist
  if not os.path.exists(folder_path):
      os.makedirs(folder_path)
  # Configure request headers for downloading
  headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5',
    'Connection': 'keep-alive',
  }
  opener = urllib.request.build_opener()
  opener.addheaders = [(key, value) for key, value in headers.items()]
  urllib.request.install_opener(opener)

  # Iterate through each file and download it
  for index, value in enumerate(files):
    try:
        # Stores each dictionary item's download link
        url = files[index]['Download link']

        # Define file path and name
        file_path = os.path.join(f"{folder_path}", f"{files[index]['Updated image name']}")
        
        # Download image
        urllib.request.urlretrieve(url, file_path)

        hrefSchema = {
            "type": "image",
            "src": f"/images{docsFolderPath if True else None}/{files[index]['Updated image name']}",
            "alt": ""
        }
        print(json.dumps(hrefSchema))
    except Exception as e:
        pass

getDictionary(URL)

# Export report to .csv
df = pd.DataFrame.from_dict(files, orient='index')
df.to_csv("image-extractor-report.csv", index=False)

# %%
from bs4 import BeautifulSoup
import requests
import re
import json
import os
import urllib.request
import shutil
import math

#######################################
#     Link Extractooooor (Website)    #
#######################################

# Define target website
url = "https://www.clc.gov.sg/events/webinar"
domain = "https://www.clc.gov.sg"

def getDictionary(link):
  count = 0

  # Pulls entire HTML code and parse it through BeautifulSoup
  page = requests.get(link)
  soup = BeautifulSoup(page.content, "html.parser")
  soup = soup.find("div", class_="sf_colsIn sf_2cols_1in_75")

  # Loop through all anchor tags to find links
  for i in soup.find_all(['a']):
    print(i)
    try:
        # Build dictionary for easier search
        files[count] = {"Text": i.text, "Link": i['alt']}
        count += 1
    except Exception as e:
        pass

getDictionary(url)
